# %%
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.9/12.9 MB 14.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.8/12.9 MB 13.9 MB/s eta 0:00:01
#    -------------------------- ------------- 8.7/12.9 MB 13.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.5/12.9 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 13.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------------- -------------------------- 2.9/8.3 MB 14.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.8/8.3 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 13.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 13.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = [0.055896375,0.027651636,0.09340934,0.09558622,0.06366366,0.09732141,0.065500095,0.019397711,0.030607129,0.03600342,0.020734467,0.031298447,0.049850542,0.018627914,0.030929796,0.05055135,0.073952906,0.0337002,0.07912141,0.06426145,0.060273673,0.07399806,0.010751286,0.06625441,0.04273713,0.079533994,0.049815193,0.05126953,0.05258538,0.099529006,0.018000456,0.026082095,0.023610735,0.04856845,0.011354837,0.022040011,0.0018469591,0.08837765,0.082854524,0.03143406,0.09720442,0.0479563,0.061394684,0.081938535,0.06590467,0.09841642,0.010161815,0.065858126,0.00095264614,0.08916936]



# 1. Create your Array(50) of Floats
# For demonstration, let's create a random array
data_1d = np.array(data)  # Example data: 50 random floats between 0 and 100

# 2. Reshape the 1D array into a 2D matrix
# Let's choose a 5x10 matrix (5 rows, 10 columns)
matrix_2d = data_1d.reshape((5, 10))

# 4. Create the Heatmap using Seaborn (often preferred for aesthetics)
plt.figure(figsize=(8, 4)) # Set the figure size
sns.heatmap(matrix_2d, annot=True, fmt=".1f", cmap='coolwarm', linewidths=.5)
# annot=True displays the values on the heatmap
# fmt=".1f" formats the annotations to one decimal place
# cmap='coolwarm' is another popular colormap
# linewidths adds lines between cells
plt.title('Heatmap using Seaborn (5x10)')
plt.xlabel('Column Index')
plt.ylabel('Row Index')
plt.show()

# Example with a different reshaping (e.g., 10x5)
matrix_2d_10x5 = data_1d.reshape((10, 5))
plt.figure(figsize=(6, 6))
sns.heatmap(matrix_2d_10x5, annot=True, fmt=".1f", cmap='plasma', linewidths=.5)
plt.title('Heatmap using Seaborn (10x5)')
plt.xlabel('Column Index')
plt.ylabel('Row Index')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List, Tuple

def plot_heatmap(data_list: List[float]):
    """
    Translates a 1D list of 50 floats into a 5x10 matrix and plots a heatmap.
    All plot parameters (title, colormap, annotations, figsize, etc.) are static.

    Args:
        data_list (List[float]): A list of exactly 50 float values.
    """
    # Static configuration
    ROWS = 10
    COLS = 16
    EXPECTED_LENGTH = ROWS * COLS
    TITLE = "Heatmap"
    CMAP = 'viridis'  # You can change this to 'coolwarm', 'plasma', etc.
    ANNOTATE = True   # Set to False if you don't want values on the heatmap
    FIGSIZE = (COLS, ROWS)

    # Type and length checks
    if not isinstance(data_list, list) or not all(isinstance(x, float) for x in data_list):
        raise TypeError("data_list must be a list containing only float values.")
    if len(data_list) != EXPECTED_LENGTH:
        raise ValueError(f"data_list must contain exactly {EXPECTED_LENGTH} float values, but got {len(data_list)}.")

    # Convert the list to a NumPy array
    data_1d = np.array(data_list)

    # Reshape the 1D array into the static 2D matrix
    matrix_2d = data_1d.reshape((ROWS, COLS))

